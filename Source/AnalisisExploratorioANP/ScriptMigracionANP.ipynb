# %%
import pandas as pd

# %%
df=pd.read_excel('Estadísticas ANPs RMBA.xlsx')

# %%
df.head()
# Out:
#     N°                             Área Natural Protegida  Superficie (ha.)  \
# 0  1.0                  Paisaje Protegido "Bosque Alegre"               3.0
# 1  2.0   Paisaje Protegido "Cuenca del arroyo El Pescado"           40000.0
# 2  3.0  Paisaje Protegido "Monte Ribereño Isla Paulino...            2300.0
# 3  4.0  Paisaje Protegido "Reserva Parque - Paseo del ...             115.0
# 4  5.0  Paisaje Protegido Barrio Parque Residencial Su...              22.0
#
#                          Ecorregión           Municipio Administración  \
# 0                             Pampa          San isidro      Municipal
# 1  Pampa y Delta e islas del Paraná            La Plata          Mixta
# 2  Pampa y Delta e islas del Paraná  Ensenada y Berisso          Mixta
# 3                             Pampa            La Plata          Mixta
# 4                             Pampa          San Martín          Mixta
#
#    Año de creación Categoría Internacional Plan de Manejo Guardaparques  \
# 0           2012.0                      No             No           NaN
# 1           1999.0                      No             No           NaN
# 2           2001.0                      No             No           NaN
# 3           2007.0                      No             No           NaN
# 4           1999.0                      No             No           NaN
#
#   Infraestructura Atención a visitantes
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN

# %%
df= df[['Área Natural Protegida', 'Superficie (ha.)', 'Ecorregión',
       'Municipio', 'Administración', 'Año de creación',
       'Categoría Internacional', 'Plan de Manejo', 'Guardaparques',
       'Infraestructura', 'Atención a visitantes']]

# %%
toNewName ={
    'Área Natural Protegida':'Nombre', 'Superficie (ha.)':'Superficie', 'Ecorregión':'Ecoregion', 'Administración':'Administracion', 'Año de creación':'AnioCreacion',
       'Categoría Internacional':'CategoriaInternacional', 'Plan de Manejo':'PlanManejo', 'Atención a visitantes':'AtencionVisitantes'
}
df = df.rename(columns=toNewName)

# %%
df[0:46].to_json(path_or_buf='anp.json', orient='records')

# %%
df[df['Guardaparques'].isnull()]
# Out:
#                                                Nombre  Superficie  \
# 0                   Paisaje Protegido "Bosque Alegre"         3.0
# 1    Paisaje Protegido "Cuenca del arroyo El Pescado"     40000.0
# 2   Paisaje Protegido "Monte Ribereño Isla Paulino...      2300.0
# 3   Paisaje Protegido "Reserva Parque - Paseo del ...       115.0
# 4   Paisaje Protegido Barrio Parque Residencial Su...        22.0
# 45           Monumento Natural Ciervo de los Pantanos         NaN
# 46                                                NaN    186484.0
#
#                           Ecorregion                             Municipio  \
# 0                              Pampa                            San isidro
# 1   Pampa y Delta e islas del Paraná                              La Plata
# 2   Pampa y Delta e islas del Paraná                    Ensenada y Berisso
# 3                              Pampa                              La Plata
# 4                              Pampa                            San Martín
# 45          Delta e Islas del Paraná  Zárate, Campana y Delta en Formación
# 46                               NaN                                   NaN
#
#    Administracion  AnioCreacion CategoriaInternacional PlanManejo  \
# 0       Municipal        2012.0                     No         No
# 1           Mixta        1999.0                     No         No
# 2           Mixta        2001.0                     No         No
# 3           Mixta        2007.0                     No         No
# 4           Mixta        1999.0                     No         No
# 45     Provincial        1998.0                     No        NaN
# 46            NaN           NaN                    NaN        NaN
#
#    Guardaparques Infraestructura AtencionVisitantes
# 0            NaN             NaN                NaN
# 1            NaN             NaN                NaN
# 2            NaN             NaN                NaN
# 3            NaN             NaN                NaN
# 4            NaN             NaN                NaN
# 45           NaN             NaN                NaN
# 46           NaN             NaN                NaN
