# %%
import pandas as pd

# %%
df=pd.read_excel('data/GRAN.xls')

# %%
df.head(46)
# Out:
#       N°                             Área Natural Protegida Superficie (ha.)  \
# 0    1.0                  Paisaje Protegido "Bosque Alegre"                3
# 1    2.0   Paisaje Protegido "Cuenca del arroyo El Pescado"            40000
# 2    3.0  Paisaje Protegido "Monte Ribereño Isla Paulino...             2300
# 3    4.0  Paisaje Protegido "Reserva Parque - Paseo del ...              115
# 4    5.0  Paisaje Protegido Barrio Parque Residencial Su...               22
# 5    6.0                      Paisaje Protegido Delta Terra               40
# 6    7.0  Parque  Natural  Municipal Barranca de la Quin...                1
# 7    8.0  Parque Ecológico Municipal (Ambiente Pastizal ...               45
# 8    9.0           Parque Municipal Dique Ingeniero Roggero             1000
# 9   10.0       Parque Natural Municipal Barranca Pueyrredón              1.5
# 10  11.0  Parque Natural y Reserva Ecológica Municipal S...              150
# 11  12.0     Parque Natural y Zona de Reserva Costanera Sur              353
# 12  13.0         Parque Provincial Guillermo Enrique Hudson               54
# 13  14.0                   Parque Provincial Pereyra Iraola             4000
# 14  15.0               Reserva de Biosfera Delta del Paraná            88624
# 15  16.0               Reserva de Uso Múltiple Isla Botija              4108
# 16  17.0  Reserva Ecológica Ciudad Universitaria - Costa...               35
# 17  18.0           Reserva Ecológica Municipal La Saladita                22
# 18  19.0                               Reserva Lago Lugano                36
# 19  20.0   Reserva Municipal Refugio Educativo Ribera Norte               50
# 20  21.0                      Reserva Natural Ciudad Evita               300
# 21  22.0             Reserva Natural Costera de Avellaneda               130
# 22  23.0                           Reserva Natural de Morón             14.5
# 23  24.0                          Reserva Natural de Toyota               23
# 24  25.0  Reserva Natural de Uso Múltiple Isla Martín Ga...              200
# 25  26.0          Reserva Natural de Uso Múltiple Río Luján             1257
# 26  27.0                         Reserva Natural del Pilar               297
# 27  28.0                         Reserva Natural El Morejón              110
# 28  29.0                Reserva Natural Guardia del Juncal               129
# 29  30.0        Reserva Natural Integral Delta en Formación            30841
# 30  31.0                Reserva Natural Integral Punta Lara             6000
# 31  32.0  Reserva Natural Integral y Mixta Laguna de Rocha               630
# 32  33.0            Reserva Natural Lagunas de San Vicente               132
# 33  34.0          Reserva Natural Municipal Santa Catalina              16.5
# 34  35.0            Reserva Natural Municipal Vicente Lopez                3
# 35  36.0                          Reserva Natural Otamendi              4088
# 36  37.0  Reserva Natural Provincial de Objetivo Definid...              435
# 37  38.0          Reserva Natural Provincial Santa Catalina              728
# 38  39.0          Reserva Natural Selva Marginal de Hudson              1200
# 39  40.0              Reserva Natural Urbana "El Corredor"                 8
# 40  41.0         Reserva Paleontologica "Francisco Moreno"                25
# 41  42.0               Reserva Privada Club Náutico Escobar                9
# 42  43.0           Reserva Privada del CEAMSE "Santa María"             43.5
# 43  44.0                 Reserva Privada el Talar de Belén                90
# 44  45.0                     Reserva Urbana Quinta Cigordia               15
# 45  46.0           Monumento Natural Ciervo de los Pantanos              n/a
#
#                           Ecorregión  \
# 0                              Pampa
# 1   Pampa y Delta e islas del Paraná
# 2   Pampa y Delta e islas del Paraná
# 3                              Pampa
# 4                              Pampa
# 5           Delta e Islas del Paraná
# 6                              Pampa
# 7                              Pampa
# 8                              Pampa
# 9                              Pampa
# 10  Pampa y Delta e islas del Paraná
# 11  Pampa y Delta e islas del Paraná
# 12                             Pampa
# 13                             Pampa
# 14          Delta e Islas del Paraná
# 15          Delta e Islas del Paraná
# 16  Pampa y Delta e islas del Paraná
# 17                             Pampa
# 18                             Pampa
# 19  Pampa y Delta e Islas del Paraná
# 20                             Pampa
# 21  Pampa y Delta e islas del Paraná
# 22                             Pampa
# 23                             Pampa
# 24          Delta e Islas del Paraná
# 25          Delta e Islas del Paraná
# 26                             Pampa
# 27                             Pampa
# 28                             Pampa
# 29          Delta e Islas del Paraná
# 30  Pampa y Delta e islas del Paraná
# 31                             Pampa
# 32                             Pampa
# 33                             Pampa
# 34  Pampa y Delta e islas del Paraná
# 35  Pampa y Delta e islas del Paraná
# 36                             Pampa
# 37                             Pampa
# 38  Pampa y Delta e islas del Paraná
# 39                             Pampa
# 40                             Pampa
# 41          Delta e Islas del Paraná
# 42                             Pampa
# 43  Pampa y Delta e islas del Paraná
# 44                             Pampa
# 45          Delta e Islas del Paraná
#
#                                             Municipio  \
# 0                                          San isidro
# 1                                            La Plata
# 2                                  Ensenada y Berisso
# 3                                            La Plata
# 4                                          San Martín
# 5                                               Tigre
# 6                                          San Isidro
# 7                                            La Plata
# 8                                              Moreno
# 9                                          San Isidro
# 10                                            Quilmes
# 11                                           C.A.B.A.
# 12                                   Florencio Varela
# 13  Berazategui, Florencio Varela, La Plata y Ense...
# 14                                       San Fernando
# 15                                             Zárate
# 16                                           C.A.B.A.
# 17                                         Avellaneda
# 18                                           C.A.B.A.
# 19                                         San Isidro
# 20                                         La Matanza
# 21                                         Avellaneda
# 22                                              Morón
# 23                                             Zárate
# 24                                              Tigre
# 25                                            Campana
# 26                                              Pilar
# 27                                            Campana
# 28                                           Cañuelas
# 29                                              Tigre
# 30                             Ensenada y Berazategui
# 31                                 Esteban Echeverría
# 32                                        San Vicente
# 33                                    Lomas de Zamora
# 34                                      Vicente López
# 35                                            Campana
# 36                                         Marcos paz
# 37                                    Lomas de Zamora
# 38                                        Berazategui
# 39                                         San Miguel
# 40                                         Marcos Paz
# 41                                            Escobar
# 42                             Ituzaingó y Hurlingham
# 43                                            Escobar
# 44                                              Luján
# 45               Zárate, Campana y Delta en Formación
#
#                                             Localidad Administración  \
# 0                                            Acassuso      Municipal
# 1   Los Hornos, Lisandro Olmos, Villa Elvira, Magd...          Mixta
# 2                                  Ensenada y Berisso          Mixta
# 3                                            La Plata          Mixta
# 4                                    José León Suarez          Mixta
# 5                                     Delta del Tigre        Privada
# 6                                          San isidro      Municipal
# 7                                         Villa Elisa      Municipal
# 8                                             La Reja      Municipal
# 9                                            Acassuso      Municipal
# 10                                 Bernal y Don Bosco      Municipal
# 11                                           C.A.B.A.      Municipal
# 12                                     Villa San Luis          Mixta
# 13  Ranelagh; Plátanos; Gutierrez; Ingeniero Allan...     Provincial
# 14       Segunda y tercera sección de islas del Delta      Municipal
# 15                                    Delta de Zárate     Provincial
# 16                                           C.A.B.A.      Municipal
# 17                                            Sarandí      Municipal
# 18                                           C.A.B.A.      Municipal
# 19                                           Acassuso      Municipal
# 20                                       Ciudad Evita      Municipal
# 21                           Sarandí y Villa Dominico      Municipal
# 22                                              Morón      Municipal
# 23                                             Zárate        Privada
# 24                                              Tigre     Provincial
# 25                                            Campana     Provincial
# 26                                              Pilar      Municipal
# 27                                            Campana        Privada
# 28                                 Gobernador Udaondo          Mixta
# 29                                              Tigre     Provincial
# 30              Ensenada, Punta Lara, Hudson, Pereyra     Provincial
# 31                                       Monte Grande          Mixta
# 32                                        San Vicente     Provincial
# 33                                           Lavallol      Municipal
# 34                                          La Lucila      Municipal
# 35                               Ing. Rómulo Otamendi       Nacional
# 36                                       Elias Romero     Provincial
# 37                                           Lavallol     Provincial
# 38                                             Hudson      Municipal
# 39                                        Bella Vista      Municipal
# 40                                         Santa Rosa      Municipal
# 41                                   Belén de Escobar        Privada
# 42                  Villa Udaondo y William C. Morris        Privada
# 43                                   Belén de Escobar        Privada
# 44                                              Luján      Municipal
# 45               Zárate, Campana y Delta en Formación     Provincial
#
#     Año de creación Categoría Internacional Plan de Manejo  \
# 0            2012.0                      No             No
# 1            1999.0                      No             No
# 2            2001.0                      No             No
# 3            2007.0                      No             No
# 4            1999.0                      No             No
# 5            2013.0                      No             Si
# 6            2009.0                      No             Si
# 7            1999.0                      No             No
# 8            1989.0                      No             Si
# 9            2009.0                      No             Si
# 10           2002.0                      No             No
# 11           1986.0     Sitio RAMSAR y AICA             Si
# 12           1999.0                      No             Si
# 13           1949.0     Reserva de Biósfera             No
# 14           2000.0     Reserva de Biósfera             Si
# 15           2010.0                      No             No
# 16           2012.0                      No             No
# 17           1994.0                      No             No
# 18           2012.0                      No             Si
# 19           1988.0                      No             Si
# 20           2015.0                      No             No
# 21           2015.0                      No             No
# 22           2011.0                      No             Si
# 23           2017.0                      No             Si
# 24           1969.0                    AICA             No
# 25           1996.0                      No             No
# 26           1991.0                      No             Si
# 27           2012.0                      No             Si
# 28           2006.0                      No             No
# 29           1999.0                      No             No
# 30           1943.0                    AICA             No
# 31           2012.0                      No             No
# 32           2011.0                      No             No
# 33           1991.0                      No             Si
# 34           1983.0                      No             Si
# 35           1990.0     Sitio RAMSAR y AICA             Si
# 36           2011.0                      No             No
# 37           2011.0                      No             No
# 38           1991.0                      No             No
# 39           2016.0                      No             No
# 40           2013.0                      No             Si
# 41           2000.0                      No             No
# 42           1996.0                      No             Si
# 43           1991.0                      No             No
# 44           1973.0                      No             Si
# 45           1998.0                      No            n/a
#
#                 ...                          Partido3  Partido4  \
# 0               ...                               NaN       NaN
# 1               ...                               NaN       NaN
# 2               ...                               NaN       NaN
# 3               ...                               NaN       NaN
# 4               ...                               NaN       NaN
# 5               ...                               NaN       NaN
# 6               ...                               NaN       NaN
# 7               ...                               NaN       NaN
# 8               ...                               NaN       NaN
# 9               ...                               NaN       NaN
# 10              ...                               NaN       NaN
# 11              ...                               NaN       NaN
# 12              ...                               NaN       NaN
# 13              ...                          La Plata  Ensenada
# 14              ...                               NaN       NaN
# 15              ...                               NaN       NaN
# 16              ...                               NaN       NaN
# 17              ...                               NaN       NaN
# 18              ...                               NaN       NaN
# 19              ...                               NaN       NaN
# 20              ...                               NaN       NaN
# 21              ...                               NaN       NaN
# 22              ...                               NaN       NaN
# 23              ...                               NaN       NaN
# 24              ...                               NaN       NaN
# 25              ...                               NaN       NaN
# 26              ...                               NaN       NaN
# 27              ...                               NaN       NaN
# 28              ...                               NaN       NaN
# 29              ...                               NaN       NaN
# 30              ...                               NaN       NaN
# 31              ...                               NaN       NaN
# 32              ...                               NaN       NaN
# 33              ...                               NaN       NaN
# 34              ...                               NaN       NaN
# 35              ...                               NaN       NaN
# 36              ...                               NaN       NaN
# 37              ...                               NaN       NaN
# 38              ...                               NaN       NaN
# 39              ...                               NaN       NaN
# 40              ...                               NaN       NaN
# 41              ...                               NaN       NaN
# 42              ...                               NaN       NaN
# 43              ...                               NaN       NaN
# 44              ...                               NaN       NaN
# 45              ...                Delta en Formación       NaN
#
#                                       Localidad1         Localidad2  \
# 0                                       Acassuso                NaN
# 1                                     Los Hornos     Lisandro Olmos
# 2                                       Ensenada            Berisso
# 3                                       La Plata                NaN
# 4                               José León Suarez                NaN
# 5                                Delta del Tigre                NaN
# 6                                     San Isidro                NaN
# 7                                    Villa Elisa                NaN
# 8                                        La Reja                NaN
# 9                                       Acassuso                NaN
# 10                                        Bernal          Don Bosco
# 11                                      C.A.B.A.                NaN
# 12                                Villa San Luis                NaN
# 13                                      Ranelagh           Plátanos
# 14  Segunda y tercera sección de islas del Delta                NaN
# 15                               Delta de Zárate                NaN
# 16                                      C.A.B.A.                NaN
# 17                                       Sarandí                NaN
# 18                                      C.A.B.A.                NaN
# 19                                      Acassuso                NaN
# 20                                  Ciudad Evita                NaN
# 21                                       Sarandí     Villa Dominico
# 22                                         Morón                NaN
# 23                                        Zárate                NaN
# 24                                         Tigre                NaN
# 25                                       Campana                NaN
# 26                                         Pilar                NaN
# 27                                       Campana                NaN
# 28                            Gobernador Udaondo                NaN
# 29                                         Tigre                NaN
# 30                                      Ensenada         Punta Lara
# 31                                  Monte Grande                NaN
# 32                                   San Vicente                NaN
# 33                                      Lavallol                NaN
# 34                                     La Lucila                NaN
# 35                          Ing. Rómulo Otamendi                NaN
# 36                                  Elias Romero                NaN
# 37                                      Lavallol                NaN
# 38                                        Hudson                NaN
# 39                                   Bella Vista                NaN
# 40                                    Santa Rosa                NaN
# 41                              Belén de Escobar                NaN
# 42                                 Villa Udaondo  William C. Morris
# 43                              Belén de Escobar                NaN
# 44                                         Luján                NaN
# 45                                        Zárate            Campana
#
#             Localidad3       Localidad4   Localidad5 Localidad6    Foto  \
# 0                  NaN              NaN          NaN        NaN   JPG.1
# 1         Villa Elvira        Magdalena          NaN        NaN   JPG.2
# 2                  NaN              NaN          NaN        NaN   JPG.3
# 3                  NaN              NaN          NaN        NaN   JPG.4
# 4                  NaN              NaN          NaN        NaN   JPG.5
# 5                  NaN              NaN          NaN        NaN   JPG.6
# 6                  NaN              NaN          NaN        NaN   JPG.7
# 7                  NaN              NaN          NaN        NaN   JPG.8
# 8                  NaN              NaN          NaN        NaN   JPG.9
# 9                  NaN              NaN          NaN        NaN  JPG.10
# 10                 NaN              NaN          NaN        NaN  JPG.11
# 11                 NaN              NaN          NaN        NaN  JPG.12
# 12                 NaN              NaN          NaN        NaN  JPG.13
# 13          Guitierrez  Ingeniero Allan  Villa Elisa   Ensenada  JPG.14
# 14                 NaN              NaN          NaN        NaN  JPG.15
# 15                 NaN              NaN          NaN        NaN  JPG.16
# 16                 NaN              NaN          NaN        NaN  JPG.17
# 17                 NaN              NaN          NaN        NaN  JPG.18
# 18                 NaN              NaN          NaN        NaN  JPG.19
# 19                 NaN              NaN          NaN        NaN  JPG.20
# 20                 NaN              NaN          NaN        NaN  JPG.21
# 21                 NaN              NaN          NaN        NaN  JPG.22
# 22                 NaN              NaN          NaN        NaN  JPG.23
# 23                 NaN              NaN          NaN        NaN  JPG.24
# 24                 NaN              NaN          NaN        NaN  JPG.25
# 25                 NaN              NaN          NaN        NaN  JPG.26
# 26                 NaN              NaN          NaN        NaN  JPG.27
# 27                 NaN              NaN          NaN        NaN  JPG.28
# 28                 NaN              NaN          NaN        NaN  JPG.29
# 29                 NaN              NaN          NaN        NaN  JPG.30
# 30              Hudson          Pereyra          NaN        NaN  JPG.31
# 31                 NaN              NaN          NaN        NaN  JPG.32
# 32                 NaN              NaN          NaN        NaN  JPG.33
# 33                 NaN              NaN          NaN        NaN  JPG.34
# 34                 NaN              NaN          NaN        NaN  JPG.35
# 35                 NaN              NaN          NaN        NaN  JPG.36
# 36                 NaN              NaN          NaN        NaN  JPG.37
# 37                 NaN              NaN          NaN        NaN  JPG.38
# 38                 NaN              NaN          NaN        NaN  JPG.39
# 39                 NaN              NaN          NaN        NaN  JPG.40
# 40                 NaN              NaN          NaN        NaN  JPG.41
# 41                 NaN              NaN          NaN        NaN  JPG.42
# 42                 NaN              NaN          NaN        NaN  JPG.43
# 43                 NaN              NaN          NaN        NaN  JPG.44
# 44                 NaN              NaN          NaN        NaN  JPG.45
# 45  Delta en Formación              NaN          NaN        NaN  JPG.46
#
#                       Unnamed: 29
# 0                              ok
# 1                          pedida
# 2                          pedida
# 3                          sacar
# 4                          pedida
# 5                          pedida
# 6                              ok
# 7                              ok
# 8                              ok
# 9                              ok
# 10                   ver facebook
# 11                             ok
# 12                             ok
# 13                             ok
# 14                         pedida
# 15                         pedida
# 16                             ok
# 17                             ok
# 18                         pedida
# 19                             ok
# 20                         pedida
# 21                             ok
# 22                             ok
# 23                         llamar
# 24          pedida a Daniel Novoa
# 25                         pedida
# 26                             ok
# 27                         pedida
# 28          pedida a Daniel Novoa
# 29          pedida a Daniel Novoa
# 30                             ok
# 31                         pedida
# 32          pedida a Daniel Novoa
# 33                         pedida
# 34                             ok
# 35  pedida ciervo de los pantanos
# 36          pedida a Daniel Novoa
# 37                         pedida
# 38                             ok
# 39                             ok
# 40                         pedida
# 41                         pedida
# 42                         pedida
# 43                         pedida
# 44                             ok
# 45          pedida a Daniel Novoa
#
# [46 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['N°', 'Área Natural Protegida', 'Superficie (ha.)', 'Ecorregión',
#        'Municipio', 'Localidad', 'Administración', 'Año de creación',
#        'Categoría Internacional', 'Plan de Manejo', 'Guardaparques',
#        'Infraestructura', 'Atención a visitantes', 'Descripcion', 'Latitud',
#        'Unnamed: 15', 'Longuitud', 'Acceso/s', 'Partido1', 'Partido2',
#        'Partido3', 'Partido4', 'Localidad1', 'Localidad2', 'Localidad3',
#        'Localidad4', 'Localidad5', 'Localidad6', 'Foto', 'Unnamed: 29'],
#       dtype='object')

# %%
df= df[['N°','Área Natural Protegida', 'Superficie (ha.)', 'Ecorregión',
       'Municipio', 'Localidad', 'Administración', 'Año de creación',
       'Categoría Internacional', 'Plan de Manejo', 'Guardaparques',
       'Infraestructura', 'Atención a visitantes' , 'Descripcion', 'Latitud', 'Longuitud']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-6c94fedc4437> in <module>
#       2        'Municipio', 'Localidad', 'Administración', 'Año de creación',
#       3        'Categoría Internacional', 'Plan de Manejo', 'Guardaparques',
# ----> 4        'Infraestructura', 'Atención a visitantes' , 'Descripcion', 'Latitud', 'Longuitud']]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['Año de creación', 'Atención a visitantes', 'Ecorregión', 'N°', 'Plan de Manejo', 'Administración', 'Superficie (ha.)', 'Área Natural Protegida', 'Longuitud', 'Categoría Internacional'] not in index"

# %%
toNewName ={
    'Área Natural Protegida':'Nombre', 'Superficie (ha.)':'Superficie', 'Ecorregión':'Ecoregion', 'Administración':'Administracion', 'Año de creación':'AnioCreacion',
       'Categoría Internacional':'CategoriaInternacional', 'Plan de Manejo':'PlanManejo', 'Atención a visitantes':'AtencionVisitantes',
    'Latitud':'Latitud', 'Longuitud':'Longitud', 'N°':'Id'
}
df = df.rename(columns=toNewName)

# %% [markdown]
# # Depurando datos nulos

# %%
df['Guardaparques'].fillna(value='No', inplace=True)

# %%
df['Id'].fillna(value=0, inplace=True)
df['Id']=df['Id'].apply(lambda x: int(x))

# %%
df['Infraestructura'].fillna(value='No', inplace=True)

# %%
df['AtencionVisitantes'].fillna(value='No', inplace=True)

# %%
df['PlanManejo'].fillna(value='No', inplace=True)

# %%
df['Superficie'].fillna(value=0, inplace=True)

# %%
df['Ecoregion'].replace('Delta e Islas del Paraná','Delta e islas del Paraná',inplace=True)

# %%
df['Ecoregion'].replace('Pampa y Delta e Islas del Paraná','Pampa y Delta e islas del Paraná',inplace=True)

# %%
df['Descripcion'].fillna(value = '-', inplace=True)

# %%
df = df[df['Id']!=0]

# %%
df[0:46].to_json(path_or_buf='anp.json', orient='records')

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, Nombre, Superficie, Ecoregion, Municipio, Localidad, Administracion, AnioCreacion, CategoriaInternacional, PlanManejo, Guardaparques, Infraestructura, AtencionVisitantes, Descripcion, Latitud, Longitud]
# Index: []

# %%
df ['Ecoregion'].value_counts()
# Out:
# Pampa                               26
# Pampa y Delta e islas del Paraná    12
# Delta e islas del Paraná             8
# Name: Ecoregion, dtype: int64
